# %%
import pandas as pd
from cmapPy.pandasGEXpress import parse

# 1. Ścieżki do pobranych plików
GCTX_PATH = "~/level5_beta_trt_cp_n720216x12328.gctx"
SIGINFO_PATH = "~/siginfo_beta.txt"
COMPOUNDINFO_PATH = "~/compoundinfo_beta.txt"
GENEINFO_PATH = "~/geneinfo_beta.txt"

# %%
print("Wczytywanie metadanych...")
siginfo = pd.read_csv(SIGINFO_PATH, sep="\t", low_memory=False)
compoundinfo = pd.read_csv(COMPOUNDINFO_PATH, sep="\t", low_memory=False)
geneinfo = pd.read_csv(GENEINFO_PATH, sep="\t", low_memory=False)
# Out:
# Wczytywanie metadanych...
